# %% [markdown]
# # 1
#
# Monoid that is not a group: nonegative integers with addition
#
# Semigroup not a monoid: positive integers with addition

# %% [markdown]
# # 2
#
# 0 -> 1, 1->6, 2->3, 3 -> 2, 4 -> 3, 5-> 6

# %% [markdown]
# # 3
# {012345}, {03}, {024}, {0}

# %% [markdown]
# # 4
#
# Yes.
#
# addition is elementwise, and elementwise operations on structures composed of elements of a group form a group

# %% [markdown]
# # 5
#
# No. [[0, 1], [0, 0]] lacks an inverse

# %% [markdown]
# # 6
#
# H is the subgroup generated by an element of N {...-2N, -N, 0, N, 2N ...}

# %% [markdown]
# # 7
#
# Group: rotations about an axis
#
# operation: perform one rotation then the other
#
# Subgroup: {0 degrees, 90 degrees, 180 degrees, 270 degrees}

# %%
# 8.1

a, b elementof G

ab = ba

|a| = m, |b| = n
m, n relatively prime


|ab| is the size of the group \<ab\> generated by ab, composed of the elements {... a⁻¹b⁻¹, e, ab, abab, ...}

since a and b commute, each element of \<ab\> can be written as a(\*i) b(\*j) by swapping elements until the a's are at the front. New elements of \<ab\> can genenerated with the rules

i, j-> i + 1, j + 1 ('multiply' by ab)
i, j-> i - m, j (a^ m = e)
i, j-> i, j - n (b^n = e)

and since m and n are relatively prime, all pairs i, j can be created. 

However, only m values of i and n values of j are distinct, so there exist (m * n) pairs i, j




examine two elements represented as different pairs of as and bs that are equal. 
(i, j) = (k, l)
    
    
left multiply by a⁻¹^k
    

(i-k, j) = (0, l)
    
a(*i-k) b(*j) = b(*l)
right multiply by b⁻¹*j
    
let x = a(*i-k) = b(*j-l)
    
left side is an element of <a> and so |x| divides m , right side is an element of <b> so |x| divides n, so |x| = 1, x = e
therefore i = k mod m and j = l mod n


# 8.2

Take a value k from <a> intersect <b> .  |k| divides m and |k| divides n. Therefore |k| = 1
# Out:
# syntax: extra token "elementof" after end of expression

# %%
9

find the prime factorization p_i, n_i of l, the least common multiple of all |a| : product(p_i^n_i) = l

for each i, pick an element a_i of G such that p_i^n_i divides |a_i| This is possible by a property of least common multiples
    
since p_i^n_i divides |a_i|, and <a_i> is cyclic, there is an element b_i of <a_i> such that |b_i| = p_i^n_i
    
since each |b_i| is relatively prime to all the others, and ab = ba for all a, b in G,
    
by the result in 8 applied repeatedly, | b_1 b_2 b_3 ...| = product(p_i ^ n_i) = l
        
so b_1 b_2 b_3 ... is the element in question
# Out:
# 9

# %%
10:
Assume G = H union K.
Pick an element h of H that is not an element of K and an element of k that is not an element of H.

Case 1:
  hk element of H.
  then h⁻¹ hk element of H (closure)
  then k element of H (contradiction)
Case 2: hk not element of H
  hk element of K (G = H union K)
  hk k⁻¹ element of K (closure)
  h element of K (contradiction)
# Out:
# syntax: line break in ":" expression

# %%
14 N mod p for p prime
15 no. take an element k not equal to e of G.

if |k| is finite, then |k| is a subgroup. if |k| is infinite, then <k> is isomorphic to N and has subgroups.
